# %% [markdown]
# # Gaikwad Twitter ISIS/White supremacy Dataset
#
# only includes references to tweets. Can be fetched by scraping data with URL hacking but the text itself is not readily available

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('.././data/gaikwad/MIWS/MIWS.csv')

# %%
print("Number of rows:", df.shape[0])

print("Number of columns:", df.shape[1])
cols = df.columns
print("Columns")
for col in cols:
    print(f"Unique values in column '{col}':")
    print(df[col].unique())
    print()
    print("  ",col)
# Out:
# Number of rows: 40536
# Number of columns: 7
# Columns
# Unique values in column 'Unnamed: 0':
# [    0     1     2 ... 20293 20294 20295]
#
#    Unnamed: 0
# Unique values in column 'Tweet_ID':
# [1416578372508000257 1415105917268336640 1416069109494665216 ...
#  1431000382994632716 1431000379303481345 1431000333581361154]
#
#    Tweet_ID
# Unique values in column 'Created_Date':
# ['2021-07-18 01:59:37' '2021-07-14 00:28:36' '2021-07-16 16:15:59' ...
#  '2021-08-26 21:07:32' '2021-08-26 21:07:31' '2021-08-26 21:07:20']
#
#    Created_Date
# Unique values in column 'Geo_Enabled':
# [False  True]
#
#    Geo_Enabled
# Unique values in column 'Geographical_Location':
# ['Undefined' "['Afghan', 'Pak', 'Pakistan']" "['USA', 'US']"
#  "['USA', 'US', 'Afghan']" "['West']" "['Afghan', 'Afghanistan']"
#  "['America']" "['USA', 'US', 'Afghan', 'Afghanistan']"
#  "['Afghan', 'Pak', 'Pakistan', 'Afghanistan']" "['Pak', 'Pakistan']"
#  "['America', 'Afghan', 'Afghanistan', 'Iraq']" "['UK']"
# ...
